# %% [markdown]
# Task 1:
#
# Read the following data set:
# https://archive.ics.uci.edu/ml/machine-learning-databases/adult/
# Rename the columns as per the description from this file:
# https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.names
# Task:
# Create a sql db from adult dataset and name it sqladb
# 1. Select 10 records from the adult sqladb
# 2. Show me the average hours per week of all men who are working in private sector
# 3. Show me the frequency table for education, occupation and relationship, separately
# 4. Are there any people who are married, working in private sector and having a masters
# degree
# 5. What is the average, minimum and maximum age group for people working in different
# sectors
# 6. Calculate age distribution by country
# 7. Compute a new column as 'Net-Capital-Gain' from the two columns 'capital-gain' and
# 'capital-loss'

# %%
# Import libraries to work with
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
import sqlite3 as db
from pandasql import sqldf

# %%
# Create global variable
pysqldf = lambda q: sqldf(q, globals())

# %%
# Create dataframe, name columns and read csv into dataframe
columnnames = ['age','workclass','fnlwgt','education','educationnum','marital_status','occupation','relationship','race','sex','capital_gain','capital_loss','hoursperweek','nativecountry', 'income']
adult = pd.read_csv('adult.data.txt', names = columnnames)

# adult = pd.DataFrame(columns=columnnames)

# %% [markdown]
# Select 10 records from the adult sqladb

# %%
pysqldf("SELECT * FROM adult LIMIT 3;")
# Out:
#    age          workclass  fnlwgt   education  educationnum  \
# 0   39          State-gov   77516   Bachelors            13
# 1   50   Self-emp-not-inc   83311   Bachelors            13
# 2   38            Private  215646     HS-grad             9
#
#         marital_status          occupation    relationship    race    sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White   Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White   Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White   Male
#
#    capital_gain  capital_loss  hoursperweek   nativecountry  income
# 0          2174             0            40   United-States   <=50K
# 1             0             0            13   United-States   <=50K
# 2             0             0            40   United-States   <=50K

# %% [markdown]
# # Show me the average hours per week of all men who are working in private sector

# %%
pysqldf("""
        SELECT 
            AVG(hoursperweek) as average 
        FROM 
            adult 
        WHERE 
            workclass = 'Private' AND sex = 'Male'
        ;""")
# Out:
#   average
# 0    None

# %% [markdown]
# Show me the frequency table for education, occupation and relationship, separately

# %%
pysqldf("""
        SELECT 
            education, COUNT(education)
        FROM 
            adult 
        GROUP BY
            education
        ;""")
# Out:
#         education  COUNT(education)
# 0            10th               933
# 1            11th              1175
# 2            12th               433
# 3         1st-4th               168
# 4         5th-6th               333
# 5         7th-8th               646
# 6             9th               514
# 7      Assoc-acdm              1067
# 8       Assoc-voc              1382
# 9       Bachelors              5355
# 10      Doctorate               413
# 11        HS-grad             10501
# 12        Masters              1723
# 13      Preschool                51
# 14    Prof-school               576
# 15   Some-college              7291

# %%
pysqldf("""
        SELECT 
            occupation, COUNT(occupation)
        FROM 
            adult 
        GROUP BY
            occupation
        ;""")
# Out:
#             occupation  COUNT(occupation)
# 0                    ?               1843
# 1         Adm-clerical               3770
# 2         Armed-Forces                  9
# 3         Craft-repair               4099
# 4      Exec-managerial               4066
# 5      Farming-fishing                994
# 6    Handlers-cleaners               1370
# 7    Machine-op-inspct               2002
# 8        Other-service               3295
# 9      Priv-house-serv                149
# 10      Prof-specialty               4140
# 11     Protective-serv                649
# 12               Sales               3650
# 13        Tech-support                928
# 14    Transport-moving               1597

# %%
pysqldf("""
        SELECT 
            relationship, COUNT(relationship)
        FROM 
            adult 
        GROUP BY
            relationship
        ;""")
# Out:
#       relationship  COUNT(relationship)
# 0          Husband                13193
# 1    Not-in-family                 8305
# 2   Other-relative                  981
# 3        Own-child                 5068
# 4        Unmarried                 3446
# 5             Wife                 1568

# %% [markdown]
# Are there any people who are married, working in private sector and having a masters degree

# %%
pysqldf("""
        SELECT 
            *
        FROM 
            adult 
        WHERE
            relationship = 'married' AND workclass = 'Private' AND education = 'Masters'
        ;""")

## NO there are no people
# Out:
# Empty DataFrame
# Columns: [age, workclass, fnlwgt, education, educationnum, marital_status, occupation, relationship, race, sex, capital_gain, capital_loss, hoursperweek, nativecountry, income]
# Index: []

# %% [markdown]
# What is the average, minimum and maximum age group for people working in different sectors

# %%
pysqldf("""
        SELECT 
            workclass, AVG(age), MIN(age), MAX(age)
        FROM 
            adult 
        GROUP BY
            workclass
        ;""")
# Out:
#            workclass   AVG(age)  MIN(age)  MAX(age)
# 0                  ?  40.960240        17        90
# 1        Federal-gov  42.590625        17        90
# 2          Local-gov  41.751075        17        90
# 3       Never-worked  20.571429        17        30
# 4            Private  36.797585        17        90
# 5       Self-emp-inc  46.017025        17        84
# 6   Self-emp-not-inc  44.969697        17        90
# 7          State-gov  39.436055        17        81
# 8        Without-pay  47.785714        19        72

# %% [markdown]
# Calculate age distribution by country

# %%
pysqldf("""
        SELECT 
            nativecountry, AVG(age)
        FROM 
            adult 
        GROUP BY
            nativecountry
        ;""")

## WHAT IS AGE DISTRBUTION??
# Out:
#                   nativecountry   AVG(age)
# 0                             ?  38.725557
# 1                      Cambodia  37.789474
# 2                        Canada  42.545455
# 3                         China  42.533333
# 4                      Columbia  39.711864
# 5                          Cuba  45.768421
# 6            Dominican-Republic  37.728571
# 7                       Ecuador  36.642857
# 8                   El-Salvador  34.132075
# 9                       England  41.155556
# 10                       France  38.965517
# 11                      Germany  39.255474
# 12                       Greece  46.206897
# 13                    Guatemala  32.421875
# 14                        Haiti  38.272727
# 15           Holand-Netherlands  32.000000
# 16                     Honduras  33.846154
# 17                         Hong  33.650000
# 18                      Hungary  49.384615
# 19                        India  38.090000
# 20                         Iran  39.418605
# ...

# %% [markdown]
# Compute a new column as 'Net-Capital-Gain' from the two columns 'capital-gain' and 'capital-loss'

# %%
# pysqldf("""
#         ALTER TABLE adult
#         ADD net-capital-gain (capital-gain - capital-loss)
#         ;""")

pysqldf("""SELECT *,(capital_gain-capital_loss) 'Net-Capital-Gain' from adult
; """)
# Out:
#        age          workclass  fnlwgt      education  educationnum  \
# 0       39          State-gov   77516      Bachelors            13
# 1       50   Self-emp-not-inc   83311      Bachelors            13
# 2       38            Private  215646        HS-grad             9
# 3       53            Private  234721           11th             7
# 4       28            Private  338409      Bachelors            13
# 5       37            Private  284582        Masters            14
# 6       49            Private  160187            9th             5
# 7       52   Self-emp-not-inc  209642        HS-grad             9
# 8       31            Private   45781        Masters            14
# 9       42            Private  159449      Bachelors            13
# 10      37            Private  280464   Some-college            10
# 11      30          State-gov  141297      Bachelors            13
# 12      23            Private  122272      Bachelors            13
# ...

# %% [markdown]
# Task 2:
#
# Read the following data set:
# https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data
# Task:
# 1. Create an sqlalchemy engine using a sample from the data set
# 2. Write two basic update queries
# 3. Write two delete queries
# 4. Write two filter queries
# 5. Write two function queries

# %% [markdown]
# Create an sqlalchemy engine using a sample from the data set

# %%
import sqlalchemy
from sqlalchemy import create_engine
import pandas as pd
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String

# %%
# Create dataframe, name columns and read csv into dataframe
columnnames = ['age','workclass','fnlwgt','education','educationnum','marital_status','occupation','relationship','race','sex','capital_gain','capital_loss','hoursperweek','nativecountry', 'income']
df = pd.read_csv('adult.data.txt', names = columnnames)
#create engine to connect tot database
engine = create_engine('sqlite:///:memory:', echo=True)
#Create instance of Base class of the db
Base = declarative_base()

# %%
# Create Adult class, which inheritates Base class and initiate all columns + rewrite the repr method
class Adult(Base):
    __tablename__ = 'adults'
    id1 = Column(Integer, primary_key=True)
    age = Column(Integer)
    workclass = Column(String)
    fnlwgt = Column(Integer)
    education = Column(String)
    educationnum = Column(Integer)
    marital_status = Column(String)
    occupation = Column(String)
    relationship = Column(String)
    race = Column(String)
    sex = Column(String)
    capital_gain = Column(Integer)
    capital_loss = Column(Integer)
    hoursperweek = Column(Integer)
    nativecountry = Column(String)
    income = Column(String)

    def __repr__(self):
        return "<Adult(id1={},age={}, workclass={}, fnlwgt={},education={}, educationnum={}, marital_status={}, occupation={}, relationship={},race={}, sex={}, capital_gain={}, capital_loss={}, hoursperweek={},nativecountry={}, income={})>" % (
            self.id1,self.age, self.workclass, self.fnlwgt,self.education, self.educationnum, self.marital_status,self.occupation, self.relationship, self.race,self.sex, self.capital_gain, self.capital_loss,self.hoursperweek, self.nativecountry, self.income)

# %%
# Get some values from the csv as a list to insert it into the db
liste = []
for row in range(10):
    for column in df.columns:
        liste.append(df[column][row])

# %%
Adult.__table__
# Out:
# Table('adults', MetaData(bind=None), Column('id1', Integer(), table=<adults>, primary_key=True, nullable=False), Column('age', Integer(), table=<adults>), Column('workclass', String(), table=<adults>), Column('fnlwgt', Integer(), table=<adults>), Column('education', String(), table=<adults>), Column('educationnum', Integer(), table=<adults>), Column('marital_status', String(), table=<adults>), Column('occupation', String(), table=<adults>), Column('relationship', String(), table=<adults>), Column('race', String(), table=<adults>), Column('sex', String(), table=<adults>), Column('capital_gain', Integer(), table=<adults>), Column('capital_loss', Integer(), table=<adults>), Column('hoursperweek', Integer(), table=<adults>), Column('nativecountry', String(), table=<adults>), Column('income', String(), table=<adults>), schema=None)

# %%
# create table using metadata 
Base.metadata.create_all(engine)
# Out:
# 2018-12-07 18:12:29,865 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# INFO:sqlalchemy.engine.base.Engine:SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2018-12-07 18:12:29,869 INFO sqlalchemy.engine.base.Engine ()
# INFO:sqlalchemy.engine.base.Engine:()
# 2018-12-07 18:12:29,877 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# INFO:sqlalchemy.engine.base.Engine:SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2018-12-07 18:12:29,879 INFO sqlalchemy.engine.base.Engine ()
# INFO:sqlalchemy.engine.base.Engine:()
# 2018-12-07 18:12:29,884 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("adults")
# INFO:sqlalchemy.engine.base.Engine:PRAGMA table_info("adults")
# 2018-12-07 18:12:29,886 INFO sqlalchemy.engine.base.Engine ()
# INFO:sqlalchemy.engine.base.Engine:()
# 2018-12-07 18:12:29,894 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE adults (
# ...

# %%
# Create a session to be able to read write and update the table, for that load session library
from sqlalchemy.orm import sessionmaker

# %%
# create sessionmaker and bind session to created engine
# Session = sessionmaker()
Session = sessionmaker(bind=engine)
Session.configure(bind=engine) 
session = Session()

# %%
# now add all the adults from the list !!!!! SOMETHING WENT WRONG, please explain in the feedback what if wrong here
# '''
for ID in range(len(liste)):
    adding = ("Adult(id1 = {0}, age={1}, workclass={2}, fnlwgt={3},education={4}, educationnum={5}, marital_status={6}, occupation={7}, relationship={8},race={9}, sex={10}, capital_gain={11}, capital_loss={12}, hoursperweek={13},nativecountry={14}, income={15})").format(ID, liste[ID+1], liste[ID+2], liste[ID+3], liste[ID+4],liste[ID+5], liste[ID+6], liste[ID+7],liste[ID+8], liste[ID+9], liste[ID+10], liste[ID+11], liste[ID+12],liste[ID+13], liste[ID+14], liste[ID+15])
    session.add(adding)
# '''
# # HELP
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\orm\session.py in add(self, instance, _warn)
#    1771         try:
# -> 1772             state = attributes.instance_state(instance)
#    1773         except exc.NO_STATE:
#
# AttributeError: 'str' object has no attribute '_sa_instance_state'
#
# During handling of the above exception, another exception occurred:
#
# UnmappedInstanceError                     Traceback (most recent call last)
# <ipython-input-41-e2d928fc5e99> in <module>()
#       3 for ID in range(len(liste)):
# ...

# %%
adding = "Adult(id1 = 1, age=39, workclass=State-gov, fnlwgt=77516,education=Bachelors, educationnum=13, marital_status=Never-married, occupation=Adm-clerical, relationship=Not-in-family,race=While, sex=male, capital_gain=2174, capital_loss=0, hoursperweek=40,nativecountry=United-States, income=<=50K)"
session.add(adding)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\orm\session.py in add(self, instance, _warn)
#    1771         try:
# -> 1772             state = attributes.instance_state(instance)
#    1773         except exc.NO_STATE:
#
# AttributeError: 'str' object has no attribute '_sa_instance_state'
#
# During handling of the above exception, another exception occurred:
#
# UnmappedInstanceError                     Traceback (most recent call last)
# <ipython-input-50-406d3f2f127d> in <module>()
#       1 adding = "Adult(id1 = 1, age=39, workclass=State-gov, fnlwgt=77516,education=Bachelors, educationnum=13, marital_status=Never-married, occupation=Adm-clerical, relationship=Not-in-family,race=While, sex=male, capital_gain=2174, capital_loss=0, hoursperweek=40,nativecountry=United-States, income=<=50K)"
# ----> 2 session.add(adding)
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-45a3ce2a2cc7> in <module>()
# ----> 1 python.__version__
#
# NameError: name 'python' is not defined
